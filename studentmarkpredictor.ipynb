# %% [markdown]
# <a href="https://colab.research.google.com/github/anjali-28-main/Students_marks_predictor_model/blob/main/studentmarkpredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bussiness Problem

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load Dataset

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2eb2e2cb-3e60-459c-800d-02800d4faf74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2eb2e2cb-3e60-459c-800d-02800d4faf74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df=pd.read_csv(io.BytesIO(uploaded['student_info.csv']))
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
df.shape
# Out:
# (200, 2)

# %% [markdown]
# Discover and Visualize the data to gain insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.scatter(x=df.study_hours,y=df.student_marks)
plt.xlabel("student study hour")
plt.ylabel("student mark")
plt.title("scatter plot of student study hour vs marks")
plt.show()

# %% [markdown]
# Prepare Data For Machine Learning Algorithm

# %%
#DATA CLEANING

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
df2=df.fillna(df.mean())

# %%
df2
# Out:
#      study_hours  student_marks
# 0       6.830000          78.50
# 1       6.560000          76.74
# 2       6.995949          78.68
# 3       5.670000          71.82
# 4       8.670000          84.19
# ..           ...            ...
# 195     7.530000          81.67
# 196     8.560000          84.68
# 197     8.940000          86.75
# 198     6.600000          78.05
# 199     8.350000          83.50
#
# [200 rows x 2 columns]

# %%
df2.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
df2.head()
# Out:
#    study_hours  student_marks
# 0     6.830000          78.50
# 1     6.560000          76.74
# 2     6.995949          78.68
# 3     5.670000          71.82
# 4     8.670000          84.19

# %%
#SPLIT DATASET

# %%
X=df2.drop("student_marks",axis="columns")
Y=df2.drop("study_hours",axis="columns")

# %%
print("shape of X =",X.shape)
print("shape of Y =",Y.shape)
# Out:
# shape of X = (200, 1)
# shape of Y = (200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=51)
print("shape of X_train =",X_train.shape)
print("shape of Y_train =",Y_train.shape)
print("shape of X_test =",X_test.shape)
print("shape of Y_test =",Y_test.shape)
# Out:
# shape of X_train = (160, 1)
# shape of Y_train = (160, 1)
# shape of X_test = (40, 1)
# shape of Y_test = (40, 1)

# %% [markdown]
# Select A Model And Train It

# %%
#y=m*x+c
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[3.93571802]])

# %%
lr.intercept_
# Out:
# array([50.44735504])

# %%
m=3.93
c=50.44
y=m*4+c
y
# Out:
# 66.16

# %%
lr.predict([[4]])[0][0].round(2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 66.19

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([[83.11381458],
#        [78.9025963 ],
#        [84.57003024],
#        [85.82946001],
#        [84.72745896],
#        [80.75238377],
#        [72.84159055],
#        [71.66087515],
#        [73.23516235],
#        [71.66087515],
#        [73.47130543],
#        [76.38373677],
#        [73.23516235],
#        [73.58937697],
#        [82.95638585],
#        [70.40144538],
#        [73.23516235],
#        [78.74516758],
#        [75.55723598],
#        [82.68088559],
#        [76.65923703],
#        [70.48015974],
#        [74.77009238],
#        [77.98143645],
#        [85.59331693],
#        [82.56281405],
#        [76.42309395],
#        [85.0423164 ],
#        [78.39095296],
#        [81.38209865],
#        [81.73631327],
#        [83.15317176],
#        [82.20859943],
#        [81.10659839],
#        [73.58937697],
#        [71.1492318 ],
#        [71.89701823],
#        [81.53952737],
#        [72.60544747],
#        [71.93637541]])

# %%
pd.DataFrame(np.c_[X_test,Y_test,y_pred],columns=["study_hours","student_marks_original","student_marks_predicted"])
# Out:
#     study_hours  student_marks_original  student_marks_predicted
# 0      8.300000                   82.02                83.113815
# 1      7.230000                   77.55                78.902596
# 2      8.670000                   84.19                84.570030
# 3      8.990000                   85.46                85.829460
# 4      8.710000                   84.03                84.727459
# 5      7.700000                   80.81                80.752384
# 6      5.690000                   73.61                72.841591
# 7      5.390000                   70.90                71.660875
# 8      5.790000                   73.14                73.235162
# 9      5.390000                   73.02                71.660875
# 10     5.850000                   75.02                73.471305
# 11     6.590000                   75.37                76.383737
# 12     5.790000                   74.44                73.235162
# ...

# %% [markdown]
# FINE TUNE PUR MODEL

# %%
lr.score(X_test,Y_test)
# Out:
# 0.9514124242154466

# %%
plt.scatter(X_train,Y_train)

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_train,lr.predict(X_train),color="r")

# %% [markdown]
# PRESENT YOUR SOLUTION

# %% [markdown]
# SAVE ML MODEL

# %%
import joblib
joblib.dump(lr,"student_mark_prediction_model.pkl")
# Out:
# ['student_mark_prediction_model.pkl']

# %%
model=joblib.load("student_mark_prediction_model.pkl")

# %%
model.predict([[5]])[0][0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 70.12594512018406

# %% [markdown]
# LAUNCH,MONITOR,MAINTAIN SYSTEM
